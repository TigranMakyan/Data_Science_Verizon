# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import PowerTransformer, OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score

# %%
from collections import Counter


# создаем собственный класс, заменяющий отрицательные
# и нулевые значения на небольшие положительные
class Replacer(BaseEstimator, TransformerMixin):
    """
    Заменяет отрицательные и нулевые значения на
    небольшое положительное значение.
    
    Параметры
    ----------
    repl: float, по умолчанию 0.1
        Значение для замены.
    """
    def __init__(self, repl_value=0.1):
        self.repl_value = repl_value
    
    # fit здесь бездельничает
    def fit(self, X, y=None):
        return self
    
    # transform выполняет всю работу: применяет преобразование 
    # с помощью заданного значения параметра repl_value
    def transform(self, X):
        if isinstance(X, pd.DataFrame):
            X[X <= 0] = self.repl_value
        else:
            X = np.where(X <= 0, self.repl_value, X)
        return X

# %%
pd.set_option('display.max_rows', 200)

# %%
data = pd.read_csv('/home/tigran/Downloads/code/Data/Verizon.csv', sep=';')
data.head()
# Out:
#   longdist internat   local int_disc    billtype  pay   age     gender  \
# 0     8.62      NaN    8.49      Нет   Бюджетный   CH  43.0    Мужской
# 1    21.27      0.0  218,12      Нет   Бюджетный   CH  60.0        NaN
# 2     6,13      0.0     NaN       Да         NaN  NaN  25.0    Женский
# 3    16.46      0.0   57,66       Да  Бесплатный  NaN  93.0    Женский
# 4      NaN      0.0   16,01       Да  Бесплатный   CC  68.0  Женский&*
#
#      marital  children   income  churn
# 0     _Женат       0.0  33935.8      0
# 1  _Одинокий       2.0  95930,6      1
# 2        NaN       2.0   295,34      1
# 3   Одинокий       0.0      NaN      1
# 4        NaN       0.0  99832,9      1

# %%
data.describe()
# Out:
#                age     children        churn
# count  1475.000000  1476.000000  1477.000000
# mean     57.585763     0.988482     0.436019
# std      22.833863     0.824541     0.496057
# min      18.000000     0.000000     0.000000
# 25%      38.000000     0.000000     0.000000
# 50%      58.000000     1.000000     0.000000
# 75%      77.000000     2.000000     1.000000
# max      97.000000     2.000000     1.000000

# %%
data[data.duplicated(keep=False)]
# Out:
#    longdist internat local int_disc   billtype pay   age   gender marital  \
# 0      8.62      NaN  8.49      Нет  Бюджетный  CH  43.0  Мужской  _Женат
# 13     8.62      NaN  8.49      Нет  Бюджетный  CH  43.0  Мужской  _Женат
# 14     8.62      NaN  8.49      Нет  Бюджетный  CH  43.0  Мужской  _Женат
#
#     children   income  churn
# 0        0.0  33935.8      0
# 13       0.0  33935.8      0
# 14       0.0  33935.8      0

# %%
data.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
cols_lst = data.columns.to_list()
uniq = [data[col].nunique() for col in cols_lst]
types = data.dtypes
pd.DataFrame({'type': types, 'n_uniq': uniq})
# Out:
#              type  n_uniq
# longdist   object    1081
# internat   object     218
# local      object    1372
# int_disc   object       2
# billtype   object       2
# pay        object       4
# age       float64      80
# gender     object       4
# marital    object       5
# children  float64       3
# income     object    1434
# churn       int64       2

# %%
for col in ['longdist', 'internat', 'local', 'income']:
    data[col] = data[col].str.replace(',', '.').astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1475 entries, 0 to 1476
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   longdist  1467 non-null   float64
#  1   internat  1469 non-null   float64
#  2   local     1466 non-null   float64
#  3   int_disc  1471 non-null   object
#  4   billtype  1450 non-null   object
#  5   pay       1470 non-null   object
#  6   age       1473 non-null   float64
#  7   gender    1469 non-null   object
#  8   marital   1471 non-null   object
#  9   children  1474 non-null   float64
#  10  income    1471 non-null   float64
#  11  churn     1475 non-null   int64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 149.8+ KB

# %%
data.isnull().sum()
# Out:
# longdist     8
# internat     6
# local        9
# int_disc     4
# billtype    25
# pay          5
# age          2
# gender       6
# marital      4
# children     1
# income       4
# churn        0
# dtype: int64

# %%
cat_cols = data.select_dtypes(include=['object']).columns.tolist()
for col in cat_cols:
    print(col, data[col].unique())
# Out:
# int_disc ['Нет' 'Да' nan]
# billtype ['Бюджетный' nan 'Бесплатный']
# pay ['CH' nan 'CC' 'CD' 'Auto']
# gender ['Мужской' nan 'Женский' 'Женский&*' 'Мужской&*']
# marital ['_Женат' '_Одинокий' nan 'Одинокий' 'Женат' 'Же&нат']

# %%
for col in ['gender', 'marital']:
    data[col] = data[col].str.replace('[*&_]', '')
for col in ['gender', 'marital']:
    print(col, data[col].unique())
# Out:
# gender ['Мужской' nan 'Женский']
# marital ['Женат' 'Одинокий' nan]
# /tmp/ipykernel_5701/2221786089.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data[col] = data[col].str.replace('[*&_]', '')

# %%
for col in cat_cols:
    print(data[col].value_counts(dropna=False))
    print('')
# Out:
# Нет    1015
# Да      456
# NaN       4
# Name: int_disc, dtype: int64
#
# Бюджетный     731
# Бесплатный    719
# NaN            25
# Name: billtype, dtype: int64
#
# CC      846
# CH      324
# Auto    297
# NaN       5
# CD        3
# Name: pay, dtype: int64
#
# Женский    743
# Мужской    726
# NaN          6
# Name: gender, dtype: int64
#
# Женат       872
# Одинокий    599
# NaN           4
# Name: marital, dtype: int64

# %%
data.loc[data['pay'] == 'CD', 'pay'] = 'CC'

# %%
data['gender_marital'] = np.where((data['gender'].isnull()) | (data['marital'].isnull()), np.NaN, data.apply(lambda x: f"{x['gender']} + {x['marital']}", axis=1))

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       longdist  internat   local int_disc    billtype   pay   age   gender  \
# 0         8.62       NaN    8.49      Нет   Бюджетный    CH  43.0  Мужской
# 1        21.27      0.00  218.12      Нет   Бюджетный    CH  60.0      NaN
# 2         6.13      0.00     NaN       Да         NaN   NaN  25.0  Женский
# 3        16.46      0.00   57.66       Да  Бесплатный   NaN  93.0  Женский
# 4          NaN      0.00   16.01       Да  Бесплатный    CC  68.0  Женский
# ...        ...       ...     ...      ...         ...   ...   ...      ...
# 1472     25.46      0.00   43.91       Да  Бесплатный  Auto  46.0  Мужской
# 1473      8.46      0.00   22.65      Нет  Бесплатный    CC  51.0  Женский
# 1474      0.00      0.00    1.65      Нет  Бесплатный  Auto  88.0  Женский
# 1475     12.86      0.04  156.51       Да   Бюджетный    CC  18.0  Женский
# 1476     14.77      0.00   30.42      Нет  Бесплатный    CH  86.0  Мужской
#
#        marital  children    income  churn      gender_marital
# 0        Женат       0.0  33935.80      0     Мужской + Женат
# 1     Одинокий       2.0  95930.60      1                 NaN
# 2          NaN       2.0    295.34      1                 NaN
# 3     Одинокий       0.0       NaN      1  Женский + Одинокий
# 4          NaN       0.0  99832.90      1                 NaN
# ...        ...       ...       ...    ...                 ...
# 1472     Женат       0.0  10689.40      0     Мужской + Женат
# 1473  Одинокий       2.0   2638.11      1  Женский + Одинокий
# 1474     Женат       2.0  80326.60      1     Женский + Женат
# 1475     Женат       0.0  13441.50      0     Женский + Женат
# 1476     Женат       0.0  92167.30      0     Мужской + Женат
#
# [1475 rows x 13 columns]>

# %%
cond = (data['age'] == 0) | (data['longdist'] == 0)
data['ratio'] = np.where(cond, 0, data['age'] / data['longdist'])

cond = (data['longdist'] == 0) | (data['internat'] == 0)
data['ratio2'] = np.where(cond, 0, data['longdist'] / data['internat'])

cond = (data['income'] == 0) | (data['age'] == 0)
data['ratio3'] = np.where(cond, 0, data['income'] / data['age'])

cond = (data['age'] == 0) | (data['children'] == 0)
data['ratio4'] = np.where(cond, 0, data['age'] / data['children'])

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop('churn', axis=1), \
                                                    data['churn'], test_size=0.3, stratify=data['churn'],\
                                                    random_state=42)

# %%
X_train.head()
# Out:
#       longdist  internat   local int_disc    billtype pay   age   gender  \
# 1110     19.37       0.0  121.68       Да   Бюджетный  CH  59.0  Женский
# 152       0.00       0.0    2.71      Нет  Бесплатный  CH  42.0  Женский
# 700      23.24       0.0   87.62      Нет   Бюджетный  CC  25.0  Женский
# 1473      8.46       0.0   22.65      Нет  Бесплатный  CC  51.0  Женский
# 1357     13.62       0.0  188.56      Нет   Бюджетный  CC  91.0  Женский
#
#        marital  children    income      gender_marital     ratio  ratio2  \
# 1110     Женат       0.0  29953.10     Женский + Женат  3.045947     0.0
# 152      Женат       1.0  82666.30     Женский + Женат  0.000000     0.0
# 700   Одинокий       0.0  91106.40  Женский + Одинокий  1.075731     0.0
# 1473  Одинокий       2.0   2638.11  Женский + Одинокий  6.028369     0.0
# 1357     Женат       1.0  82051.90     Женский + Женат  6.681351     0.0
#
#            ratio3  ratio4
# 1110   507.679661     0.0
# 152   1968.245238    42.0
# 700   3644.256000     0.0
# 1473    51.727647    25.5
# 1357   901.669231    91.0

# %%
cat_columns = X_train.select_dtypes(include='object').columns.tolist()
num_columns = X_train.select_dtypes(exclude='object').columns.tolist()

# %%
cat_pipe = Pipeline([
    ('imp', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(sparse=False, handle_unknown='ignore'))
])

num_pipe = Pipeline([
    ('imp', SimpleImputer()),
    ('repl', Replacer(repl_value=0.1)),
    ('boxcox', PowerTransformer(method='box-cox', standardize=True))
])

# %%
transformers = [('cat', cat_pipe, cat_columns), ('num', num_pipe, num_columns)]

# %%
ct = ColumnTransformer(transformers=transformers)

# %%
ml_pipe = Pipeline([
    ('tr', ct),
    ('logreg', LogisticRegression(solver='liblinear'))
])

# %%
ml_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tr',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imp',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['int_disc', 'billtype',
#                                                    'pay', 'gender', 'marital',
#                                                    'gender_marital']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imp',
#                                                                    SimpleImputer()),
#                                                                   ('repl',
#                                                                    Replacer()),
#                                                                   ('boxcox',
#                                                                    PowerTransformer(method='box-cox'))]),
#                                                   ['longdist', 'internat',
#                                                    'local', 'age', 'children',
#                                                    'income', 'ratio', 'ratio2',
#                                                    'ratio3', 'ratio4'])])),
#                 ('logreg', LogisticRegression(solver='liblinear'))])

# %%
print('AUC_ROC on train subset : {:.3f}'.format(roc_auc_score(y_train, ml_pipe.predict_proba(X_train)[:, 1])))
# Out:
# AUC_ROC on train subset : 0.882

# %%
print('AUC_ROC on test subset : {:.3f}'.format(roc_auc_score(y_test, ml_pipe.predict_proba(X_test)[:, 1])))
# Out:
# AUC_ROC on test subset : 0.874

# %%
param_grid = {
    'tr__num__imp__strategy': ['mean', 'median', 'constant'],
    'tr__num__repl__repl_value': [0.1, 0.2, 0.3],
    'tr__cat__imp__strategy': ['most_frequent', 'constant'],
    'logreg__C': np.logspace(-2, 1, 10)
}

# %%
gs = GridSearchCV(ml_pipe, param_grid, cv=5, scoring='roc_auc')
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tr',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          Pipeline(steps=[('imp',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         sparse=False))]),
#                                                                          ['int_disc',
#                                                                           'billtype',
#                                                                           'pay',
#                                                                           'gender',
#                                                                           'marital',
#                                                                           'gender_marital']),
#                                                                         ('num',
#                                                                          Pipeline(steps=[('imp',
#                                                                                           SimpleImputer()),
#                                                                                          ('repl',
#                                                                                           Replacer()),
#                                                                                          (...
#                                                                           'ratio4'])])),
#                                        ('logreg',
#                                         LogisticRegression(solver='liblinear'))]),
#              param_grid={'logreg__C': array([ 0.01      ,  0.02154435,  0.04641589,  0.1       ,  0.21544347,
#         0.46415888,  1.        ,  2.15443469,  4.64158883, 10.        ]),
#                          'tr__cat__imp__strategy': ['most_frequent',
#                                                     'constant'],
#                          'tr__num__imp__strategy': ['mean', 'median',
#                                                     'constant'],
#                          'tr__num__repl__repl_value': [0.1, 0.2, 0.3]},
#              scoring='roc_auc')

# %%
print('Hyperparameters best combination is: ', gs.best_params_)
print('Best ROC_AUC score: ', gs.best_score_)
print('AUC_ROC on test set: ', roc_auc_score(y_test, gs.predict_proba(X_test)[:, 1]))
# Out:
# Hyperparameters best combination is:  {'logreg__C': 0.021544346900318832, 'tr__cat__imp__strategy': 'constant', 'tr__num__imp__strategy': 'constant', 'tr__num__repl__repl_value': 0.3}
# Best ROC_AUC score:  0.8727492175768038
# AUC_ROC on test set:  0.8738031088082903

# %%
results = pd.DataFrame(gs.cv_results_)

# %%
table = results.pivot_table(values=['mean_test_score'], \
                           index=['param_logreg__C',\
                                  'param_tr__num__imp__strategy',\
                                  'param_tr__num__repl__repl_value',\
                                  'param_tr__cat__imp__strategy'])

# %%
table.sort_values('mean_test_score', ascending=False, inplace=True)

# %%
table
# Out:
#                                                                                                            mean_test_score
# param_logreg__C param_tr__num__imp__strategy param_tr__num__repl__repl_value param_tr__cat__imp__strategy
# 0.021544        constant                     0.3                             constant                             0.872749
# 0.215443        constant                     0.3                             constant                             0.872732
# 4.641589        constant                     0.3                             most_frequent                        0.872709
# 10.000000       constant                     0.3                             most_frequent                        0.872672
# 2.154435        constant                     0.3                             most_frequent                        0.872670
# 1.000000        constant                     0.3                             most_frequent                        0.872593
# 0.100000        constant                     0.3                             constant                             0.872521
# 0.021544        constant                     0.3                             most_frequent                        0.872518
# 0.464159        constant                     0.3                             constant                             0.872482
#                                                                              most_frequent                        0.872478
# 4.641589        constant                     0.3                             constant                             0.872410
# 1.000000        constant                     0.3                             constant                             0.872388
# 2.154435        constant                     0.3                             constant                             0.872334
# 0.215443        constant                     0.3                             most_frequent                        0.872291
# 0.100000        constant                     0.3                             most_frequent                        0.872290
# 10.000000       constant                     0.3                             constant                             0.872162
# 0.046416        constant                     0.3                             constant                             0.872142
#                                                                              most_frequent                        0.872138
# 2.154435        constant                     0.2                             most_frequent                        0.872061
# 0.215443        constant                     0.2                             constant                             0.871949
# 4.641589        constant                     0.2                             most_frequent                        0.871927
# 10.000000       constant                     0.2                             most_frequent                        0.871926
# 0.100000        constant                     0.2                             constant                             0.871853
# 1.000000        constant                     0.2                             constant                             0.871664
# 0.215443        constant                     0.2                             most_frequent                        0.871661
# 10.000000       median                       0.3                             most_frequent                        0.871647
# 2.154435        constant                     0.2                             constant                             0.871646
# 0.100000        constant                     0.2                             most_frequent                        0.871624
# 0.464159        constant                     0.2                             most_frequent                        0.871601
#                                                                              constant                             0.871586
# 1.000000        constant                     0.2                             most_frequent                        0.871584
# 10.000000       median                       0.3                             constant                             0.871520
# 4.641589        median                       0.3                             most_frequent                        0.871494
# 0.100000        median                       0.3                             constant                             0.871461
# 2.154435        median                       0.3                             most_frequent                        0.871380
# 0.021544        median                       0.3                             constant                             0.871345
# 4.641589        median                       0.3                             constant                             0.871310
# 1.000000        median                       0.3                             most_frequent                        0.871302
# 0.215443        median                       0.3                             constant                             0.871288
# 0.464159        median                       0.3                             most_frequent                        0.871265
# 0.100000        median                       0.3                             most_frequent                        0.871229
# 0.215443        median                       0.3                             most_frequent                        0.871209
# 0.010000        constant                     0.3                             constant                             0.871177
# 0.021544        median                       0.3                             most_frequent                        0.871174
# 4.641589        constant                     0.2                             constant                             0.871094
# 0.046416        constant                     0.2                             constant                             0.871073
# 10.000000       mean                         0.3                             constant                             0.871058
# 2.154435        median                       0.3                             constant                             0.871043
# 0.464159        median                       0.3                             constant                             0.871041
# 0.010000        constant                     0.3                             most_frequent                        0.870908
# 0.046416        median                       0.3                             constant                             0.870890
# 0.100000        median                       0.2                             constant                             0.870869
# 2.154435        median                       0.2                             most_frequent                        0.870847
# 0.100000        median                       0.2                             most_frequent                        0.870829
# 1.000000        median                       0.3                             constant                             0.870813
# 0.046416        constant                     0.2                             most_frequent                        0.870786
# 10.000000       median                       0.2                             most_frequent                        0.870770
# 2.154435        constant                     0.1                             most_frequent                        0.870746
# 10.000000       constant                     0.2                             constant                             0.870733
# 4.641589        median                       0.2                             most_frequent                        0.870732
# 1.000000        constant                     0.1                             most_frequent                        0.870727
# 0.215443        median                       0.2                             constant                             0.870717
# 0.464159        median                       0.2                             most_frequent                        0.870714
# 0.046416        median                       0.3                             most_frequent                        0.870697
# 10.000000       constant                     0.1                             most_frequent                        0.870691
# 4.641589        mean                         0.3                             constant                             0.870640
# 0.100000        mean                         0.3                             most_frequent                        0.870619
# 1.000000        median                       0.2                             most_frequent                        0.870582
#                 constant                     0.1                             constant                             0.870579
# 0.100000        mean                         0.3                             constant                             0.870563
# 0.215443        median                       0.2                             most_frequent                        0.870541
# 10.000000       median                       0.2                             constant                             0.870527
# 0.021544        mean                         0.3                             constant                             0.870504
# 0.010000        median                       0.3                             constant                             0.870498
# 0.215443        mean                         0.3                             constant                             0.870486
# 2.154435        mean                         0.3                             most_frequent                        0.870441
#                                                                              constant                             0.870430
# 4.641589        constant                     0.1                             most_frequent                        0.870424
# 1.000000        mean                         0.3                             constant                             0.870332
# 0.464159        constant                     0.1                             constant                             0.870329
# 2.154435        constant                     0.1                             constant                             0.870312
# 4.641589        mean                         0.3                             most_frequent                        0.870307
# 1.000000        median                       0.2                             constant                             0.870283
# 0.010000        median                       0.3                             most_frequent                        0.870268
# 4.641589        median                       0.2                             constant                             0.870260
# 10.000000       mean                         0.3                             most_frequent                        0.870174
#                                              0.2                             constant                             0.870163
# 0.021544        constant                     0.2                             constant                             0.870160
# 1.000000        mean                         0.3                             most_frequent                        0.870136
# 0.046416        mean                         0.3                             most_frequent                        0.870123
# 4.641589        mean                         0.2                             constant                             0.870106
# 0.021544        mean                         0.3                             most_frequent                        0.870103
# 0.215443        mean                         0.3                             most_frequent                        0.870083
# 0.464159        constant                     0.1                             most_frequent                        0.870059
# 2.154435        median                       0.2                             constant                             0.870051
# 0.215443        mean                         0.2                             constant                             0.870048
# 0.464159        mean                         0.3                             most_frequent                        0.870003
#                 median                       0.2                             constant                             0.869974
# 0.100000        mean                         0.2                             constant                             0.869972
#                                                                              most_frequent                        0.869970
# 0.464159        mean                         0.3                             constant                             0.869970
# 10.000000       median                       0.1                             constant                             0.869882
#                 constant                     0.1                             constant                             0.869877
# 4.641589        constant                     0.1                             constant                             0.869799
# 0.215443        mean                         0.2                             most_frequent                        0.869797
# 10.000000       median                       0.1                             most_frequent                        0.869779
# 2.154435        mean                         0.2                             most_frequent                        0.869775
# 0.046416        mean                         0.3                             constant                             0.869742
# 0.021544        constant                     0.2                             most_frequent                        0.869739
# 10.000000       mean                         0.2                             most_frequent                        0.869736
# 4.641589        mean                         0.2                             most_frequent                        0.869679
# 0.046416        median                       0.2                             constant                             0.869670
# 1.000000        mean                         0.2                             constant                             0.869649
# 2.154435        mean                         0.2                             constant                             0.869631
# 0.010000        constant                     0.2                             constant                             0.869615
# 0.215443        constant                     0.1                             constant                             0.869602
# 4.641589        median                       0.1                             most_frequent                        0.869589
# 0.010000        mean                         0.3                             constant                             0.869581
# 0.046416        median                       0.2                             most_frequent                        0.869515
# 0.010000        mean                         0.3                             most_frequent                        0.869485
# 4.641589        median                       0.1                             constant                             0.869443
# 0.464159        mean                         0.2                             most_frequent                        0.869434
# 1.000000        mean                         0.2                             most_frequent                        0.869433
# 0.215443        constant                     0.1                             most_frequent                        0.869410
# 0.010000        constant                     0.2                             most_frequent                        0.869364
# 2.154435        median                       0.1                             most_frequent                        0.869322
# 10.000000       mean                         0.1                             constant                             0.869192
# 1.000000        median                       0.1                             most_frequent                        0.869189
# 0.021544        median                       0.2                             constant                             0.869177
# 0.464159        mean                         0.2                             constant                             0.869133
# 1.000000        median                       0.1                             constant                             0.869025
# 2.154435        median                       0.1                             constant                             0.869024
# 0.046416        mean                         0.2                             most_frequent                        0.868980
# 0.464159        median                       0.1                             most_frequent                        0.868980
# 10.000000       mean                         0.1                             most_frequent                        0.868955
# 4.641589        mean                         0.1                             most_frequent                        0.868937
# 0.021544        median                       0.2                             most_frequent                        0.868909
# 0.046416        mean                         0.2                             constant                             0.868887
# 0.100000        constant                     0.1                             constant                             0.868879
# 2.154435        mean                         0.1                             most_frequent                        0.868728
# 0.010000        median                       0.2                             constant                             0.868669
# 4.641589        mean                         0.1                             constant                             0.868601
# 0.100000        constant                     0.1                             most_frequent                        0.868514
# 0.464159        median                       0.1                             constant                             0.868507
# 0.010000        median                       0.2                             most_frequent                        0.868456
# 2.154435        mean                         0.1                             constant                             0.868392
# 1.000000        mean                         0.1                             constant                             0.868353
#                                                                              most_frequent                        0.868348
# 0.046416        constant                     0.1                             constant                             0.868327
# 0.021544        mean                         0.2                             most_frequent                        0.868315
#                                                                              constant                             0.868297
# 0.215443        median                       0.1                             most_frequent                        0.868273
# 0.010000        mean                         0.2                             constant                             0.868096
# 0.021544        constant                     0.1                             constant                             0.868082
# 0.046416        constant                     0.1                             most_frequent                        0.868038
# 0.100000        median                       0.1                             most_frequent                        0.867986
# 0.215443        median                       0.1                             constant                             0.867933
# 0.100000        median                       0.1                             constant                             0.867933
# 0.464159        mean                         0.1                             most_frequent                        0.867891
#                                                                              constant                             0.867856
# 0.021544        constant                     0.1                             most_frequent                        0.867830
# 0.010000        mean                         0.2                             most_frequent                        0.867712
# 0.215443        mean                         0.1                             constant                             0.867416
# 0.046416        median                       0.1                             constant                             0.867303
# 0.215443        mean                         0.1                             most_frequent                        0.867242
# 0.021544        median                       0.1                             most_frequent                        0.867172
#                                                                              constant                             0.866888
# 0.046416        median                       0.1                             most_frequent                        0.866882
# 0.010000        constant                     0.1                             constant                             0.866715
# 0.100000        mean                         0.1                             most_frequent                        0.866670
#                                                                              constant                             0.866521
# 0.010000        constant                     0.1                             most_frequent                        0.866484
# 0.021544        mean                         0.1                             constant                             0.866316
#                                                                              most_frequent                        0.866179
# 0.046416        mean                         0.1                             constant                             0.866121
#                                                                              most_frequent                        0.865929
# 0.010000        median                       0.1                             constant                             0.865828
#                                                                              most_frequent                        0.865730
#                 mean                         0.1                             constant                             0.865216
#                                                                              most_frequent                        0.864889
